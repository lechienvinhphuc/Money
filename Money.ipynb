# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import SGD, RMSprop,Adam
from tensorflow.keras.utils import to_categorical, load_img, img_to_array
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
import numpy as np
from keras.utils import np_utils
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense,Flatten, Dropout, Conv2D, MaxPooling2D

# %%
train = ImageDataGenerator(rescale=1/255)
train_url = '/content/drive/MyDrive/Colab Notebooks/Money'

validation = ImageDataGenerator(rescale=1/255)
validation_url = '/content/drive/MyDrive/Colab Notebooks/Money'

# %%
train_generator = ImageDataGenerator(rotation_range = 10,
                                     zoom_range = 0.1,
                                     height_shift_range = 0.1,
                                     width_shift_range = 0.1,
                                     brightness_range = (0.9,1.1))
train_dataset = train_generator.flow_from_directory(train_url,
                                                    target_size = (150,150),
                                                    batch_size = 128,
                                                    class_mode = 'categorical')
validation_dataset = validation.flow_from_directory(validation_url,
                                                       target_size = (150,150),
                                                       batch_size = 128,
                                                       class_mode = 'categorical')
# Out:
# Found 33 images belonging to 11 classes.
# Found 33 images belonging to 11 classes.

# %%
train_dataset.class_indices
# Out:
# {'100k': 0,
#  '10k': 1,
#  '1k': 2,
#  '200d': 3,
#  '200k': 4,
#  '20k': 5,
#  '2k': 6,
#  '500d': 7,
#  '500k': 8,
#  '50k': 9,
#  '5k': 10}

# %%
model = Sequential()
model.add(Conv2D(16,(3,3),activation = 'relu',padding='same',input_shape=(150,150,3)))
model.add(Conv2D(16,(3,3),activation = 'relu',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(32,(3,3),activation = 'relu',padding='same'))
model.add(Conv2D(32,(3,3),activation = 'relu',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(64,(3,3),activation = 'relu',padding='same'))
model.add(Conv2D(64,(3,3),activation = 'relu',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(128,(3,3),activation = 'relu',padding='same'))
model.add(Conv2D(128,(3,3),activation = 'relu',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(256,activation='relu',))
model.add(Dropout(0.2))
model.add(Dense(11,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 16)      448
#
#  conv2d_1 (Conv2D)           (None, 150, 150, 16)      2320
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 16)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 75, 75, 32)        4640
#
#  conv2d_3 (Conv2D)           (None, 75, 75, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 37, 37, 64)        18496
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 18, 18, 128)       73856
#
#  conv2d_7 (Conv2D)           (None, 18, 18, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 10368)             0
#
#  dense (Dense)               (None, 256)               2654464
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 11)                2827
#
# =================================================================
# Total params: 2,950,811
# Trainable params: 2,950,811
# Non-trainable params: 0
# _________________________________________________________________

# %%
#opt = SGD(lr=0.001, momentum=0.9)
model.compile(optimizer= Adam(), loss='categorical_crossentropy', metrics = ['accuracy'])

# %%
history = model.fit(train_dataset,batch_size=12,epochs=100,verbose=1,validation_data=validation_dataset)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 5s 5s/step - loss: 10.3298 - accuracy: 0.1515 - val_loss: 2.4035 - val_accuracy: 0.0909
# Epoch 2/100
# 1/1 [==============================] - 3s 3s/step - loss: 35.5199 - accuracy: 0.0909 - val_loss: 2.3980 - val_accuracy: 0.0909
# Epoch 3/100
# 1/1 [==============================] - 3s 3s/step - loss: 16.3750 - accuracy: 0.1212 - val_loss: 2.3974 - val_accuracy: 0.0909
# Epoch 4/100
# 1/1 [==============================] - 3s 3s/step - loss: 4.7554 - accuracy: 0.0606 - val_loss: 2.3978 - val_accuracy: 0.0909
# Epoch 5/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.7082 - accuracy: 0.0303 - val_loss: 2.3979 - val_accuracy: 0.0909
# Epoch 6/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.4713 - accuracy: 0.2121 - val_loss: 2.3979 - val_accuracy: 0.0909
# Epoch 7/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.4067 - accuracy: 0.0606 - val_loss: 2.3979 - val_accuracy: 0.0909
# Epoch 8/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.3480 - accuracy: 0.0909 - val_loss: 2.3979 - val_accuracy: 0.0909
# Epoch 9/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.3786 - accuracy: 0.0909 - val_loss: 2.3979 - val_accuracy: 0.0909
# Epoch 10/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.3615 - accuracy: 0.0606 - val_loss: 2.3979 - val_accuracy: 0.0909
# Epoch 11/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.3475 - accuracy: 0.2121 - val_loss: 2.3979 - val_accuracy: 0.0909
# Epoch 12/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.3866 - accuracy: 0.0909 - val_loss: 2.3979 - val_accuracy: 0.0909
# Epoch 13/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.2986 - accuracy: 0.2424 - val_loss: 2.3979 - val_accuracy: 0.0909
# Epoch 14/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.3982 - accuracy: 0.1515 - val_loss: 2.3978 - val_accuracy: 0.0909
# Epoch 15/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.2922 - accuracy: 0.1515 - val_loss: 2.3978 - val_accuracy: 0.0909
# Epoch 16/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.3151 - accuracy: 0.2424 - val_loss: 2.3978 - val_accuracy: 0.0909
# Epoch 17/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.1995 - accuracy: 0.2121 - val_loss: 2.3977 - val_accuracy: 0.0909
# Epoch 18/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.0575 - accuracy: 0.3333 - val_loss: 2.3975 - val_accuracy: 0.0909
# Epoch 19/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.9333 - accuracy: 0.4848 - val_loss: 2.3968 - val_accuracy: 0.0909
# Epoch 20/100
# 1/1 [==============================] - 3s 3s/step - loss: 3.3446 - accuracy: 0.1212 - val_loss: 2.3972 - val_accuracy: 0.0909
# Epoch 21/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.9315 - accuracy: 0.0909 - val_loss: 2.3975 - val_accuracy: 0.1212
# Epoch 22/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.7234 - accuracy: 0.0909 - val_loss: 2.3976 - val_accuracy: 0.0909
# Epoch 23/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.5251 - accuracy: 0.0909 - val_loss: 2.3977 - val_accuracy: 0.0909
# Epoch 24/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.4440 - accuracy: 0.0606 - val_loss: 2.3977 - val_accuracy: 0.0909
# Epoch 25/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.3766 - accuracy: 0.1818 - val_loss: 2.3978 - val_accuracy: 0.0909
# Epoch 26/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.3671 - accuracy: 0.1818 - val_loss: 2.3978 - val_accuracy: 0.0909
# Epoch 27/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.3833 - accuracy: 0.1515 - val_loss: 2.3978 - val_accuracy: 0.0909
# Epoch 28/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.3855 - accuracy: 0.0606 - val_loss: 2.3978 - val_accuracy: 0.0909
# Epoch 29/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.3461 - accuracy: 0.1212 - val_loss: 2.3978 - val_accuracy: 0.1212
# Epoch 30/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.3383 - accuracy: 0.2121 - val_loss: 2.3978 - val_accuracy: 0.0909
# Epoch 31/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.3494 - accuracy: 0.1515 - val_loss: 2.3977 - val_accuracy: 0.0909
# Epoch 32/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.3125 - accuracy: 0.2121 - val_loss: 2.3977 - val_accuracy: 0.0909
# Epoch 33/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.2769 - accuracy: 0.1818 - val_loss: 2.3975 - val_accuracy: 0.0909
# Epoch 34/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.2704 - accuracy: 0.0909 - val_loss: 2.3972 - val_accuracy: 0.0909
# Epoch 35/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.1994 - accuracy: 0.2727 - val_loss: 2.3966 - val_accuracy: 0.0909
# Epoch 36/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.1507 - accuracy: 0.3030 - val_loss: 2.3956 - val_accuracy: 0.0909
# Epoch 37/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.3019 - accuracy: 0.0909 - val_loss: 2.3967 - val_accuracy: 0.2424
# Epoch 38/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.2406 - accuracy: 0.2727 - val_loss: 2.3967 - val_accuracy: 0.0909
# Epoch 39/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.3708 - accuracy: 0.1212 - val_loss: 2.3970 - val_accuracy: 0.0909
# Epoch 40/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.4094 - accuracy: 0.0909 - val_loss: 2.3971 - val_accuracy: 0.0909
# Epoch 41/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.3730 - accuracy: 0.1515 - val_loss: 2.3971 - val_accuracy: 0.0909
# Epoch 42/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.3466 - accuracy: 0.1515 - val_loss: 2.3969 - val_accuracy: 0.0909
# Epoch 43/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.2997 - accuracy: 0.2424 - val_loss: 2.3962 - val_accuracy: 0.0909
# Epoch 44/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.0609 - accuracy: 0.3333 - val_loss: 2.3933 - val_accuracy: 0.2121
# Epoch 45/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.9648 - accuracy: 0.3030 - val_loss: 2.3877 - val_accuracy: 0.1515
# Epoch 46/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.2352 - accuracy: 0.1515 - val_loss: 2.3940 - val_accuracy: 0.1818
# Epoch 47/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.9971 - accuracy: 0.3030 - val_loss: 2.3967 - val_accuracy: 0.1212
# Epoch 48/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.1865 - accuracy: 0.1818 - val_loss: 2.3973 - val_accuracy: 0.0909
# Epoch 49/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.2645 - accuracy: 0.2424 - val_loss: 2.3974 - val_accuracy: 0.0909
# Epoch 50/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.2114 - accuracy: 0.1818 - val_loss: 2.3974 - val_accuracy: 0.0909
# Epoch 51/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.2584 - accuracy: 0.2121 - val_loss: 2.3973 - val_accuracy: 0.0606
# Epoch 52/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.2422 - accuracy: 0.2424 - val_loss: 2.3971 - val_accuracy: 0.0909
# Epoch 53/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.1421 - accuracy: 0.3333 - val_loss: 2.3967 - val_accuracy: 0.1212
# Epoch 54/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.0494 - accuracy: 0.3030 - val_loss: 2.3957 - val_accuracy: 0.1212
# Epoch 55/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.9339 - accuracy: 0.3636 - val_loss: 2.3937 - val_accuracy: 0.1212
# Epoch 56/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.8799 - accuracy: 0.4242 - val_loss: 2.3879 - val_accuracy: 0.1818
# Epoch 57/100
# 1/1 [==============================] - 3s 3s/step - loss: 2.2011 - accuracy: 0.3636 - val_loss: 2.3890 - val_accuracy: 0.1515
# Epoch 58/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.6831 - accuracy: 0.4848 - val_loss: 2.3896 - val_accuracy: 0.1515
# Epoch 59/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.8437 - accuracy: 0.3333 - val_loss: 2.3884 - val_accuracy: 0.1818
# Epoch 60/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.7973 - accuracy: 0.3636 - val_loss: 2.3861 - val_accuracy: 0.1818
# Epoch 61/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.8297 - accuracy: 0.3939 - val_loss: 2.3842 - val_accuracy: 0.1818
# Epoch 62/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.6939 - accuracy: 0.4848 - val_loss: 2.3805 - val_accuracy: 0.2121
# Epoch 63/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.7086 - accuracy: 0.3939 - val_loss: 2.3753 - val_accuracy: 0.2121
# Epoch 64/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.7222 - accuracy: 0.3333 - val_loss: 2.3731 - val_accuracy: 0.2121
# Epoch 65/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.6826 - accuracy: 0.3636 - val_loss: 2.3823 - val_accuracy: 0.1818
# Epoch 66/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.4852 - accuracy: 0.4848 - val_loss: 2.3857 - val_accuracy: 0.1515
# Epoch 67/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.9371 - accuracy: 0.3636 - val_loss: 2.3865 - val_accuracy: 0.1212
# Epoch 68/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.8981 - accuracy: 0.2424 - val_loss: 2.3862 - val_accuracy: 0.1212
# Epoch 69/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.4962 - accuracy: 0.4545 - val_loss: 2.3835 - val_accuracy: 0.1515
# Epoch 70/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.6726 - accuracy: 0.3333 - val_loss: 2.3841 - val_accuracy: 0.1515
# Epoch 71/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.6798 - accuracy: 0.4545 - val_loss: 2.3836 - val_accuracy: 0.2121
# Epoch 72/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.3257 - accuracy: 0.6667 - val_loss: 2.3808 - val_accuracy: 0.1818
# Epoch 73/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.4694 - accuracy: 0.5455 - val_loss: 2.3837 - val_accuracy: 0.2727
# Epoch 74/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.3093 - accuracy: 0.5758 - val_loss: 2.3848 - val_accuracy: 0.1818
# Epoch 75/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.4249 - accuracy: 0.4848 - val_loss: 2.3844 - val_accuracy: 0.2121
# Epoch 76/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.2235 - accuracy: 0.6061 - val_loss: 2.3821 - val_accuracy: 0.2727
# Epoch 77/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.1381 - accuracy: 0.5152 - val_loss: 2.3780 - val_accuracy: 0.3030
# Epoch 78/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.0798 - accuracy: 0.5152 - val_loss: 2.3723 - val_accuracy: 0.2121
# Epoch 79/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.9272 - accuracy: 0.6970 - val_loss: 2.3678 - val_accuracy: 0.1212
# Epoch 80/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.0457 - accuracy: 0.6364 - val_loss: 2.3712 - val_accuracy: 0.2727
# Epoch 81/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.4932 - accuracy: 0.5152 - val_loss: 2.3721 - val_accuracy: 0.2424
# Epoch 82/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.3667 - accuracy: 0.6364 - val_loss: 2.3715 - val_accuracy: 0.2121
# Epoch 83/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.0058 - accuracy: 0.6061 - val_loss: 2.3679 - val_accuracy: 0.3939
# Epoch 84/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.0200 - accuracy: 0.5455 - val_loss: 2.3656 - val_accuracy: 0.2424
# Epoch 85/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.1245 - accuracy: 0.5758 - val_loss: 2.3633 - val_accuracy: 0.1818
# Epoch 86/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.3431 - accuracy: 0.5758 - val_loss: 2.3642 - val_accuracy: 0.2424
# Epoch 87/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.6758 - accuracy: 0.7879 - val_loss: 2.3671 - val_accuracy: 0.1818
# Epoch 88/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.7915 - accuracy: 0.7879 - val_loss: 2.3713 - val_accuracy: 0.1818
# Epoch 89/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.7647 - accuracy: 0.7576 - val_loss: 2.3733 - val_accuracy: 0.1515
# Epoch 90/100
# 1/1 [==============================] - 3s 3s/step - loss: 1.0347 - accuracy: 0.5455 - val_loss: 2.3729 - val_accuracy: 0.1515
# Epoch 91/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.8744 - accuracy: 0.7273 - val_loss: 2.3714 - val_accuracy: 0.1515
# Epoch 92/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.9588 - accuracy: 0.6970 - val_loss: 2.3692 - val_accuracy: 0.1818
# Epoch 93/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.7321 - accuracy: 0.6667 - val_loss: 2.3679 - val_accuracy: 0.2121
# Epoch 94/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.6507 - accuracy: 0.7576 - val_loss: 2.3660 - val_accuracy: 0.3030
# Epoch 95/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.7561 - accuracy: 0.7576 - val_loss: 2.3676 - val_accuracy: 0.2424
# Epoch 96/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5910 - accuracy: 0.7879 - val_loss: 2.3687 - val_accuracy: 0.2121
# Epoch 97/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.4593 - accuracy: 0.7879 - val_loss: 2.3698 - val_accuracy: 0.1818
# Epoch 98/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.3390 - accuracy: 0.9091 - val_loss: 2.3701 - val_accuracy: 0.1818
# Epoch 99/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5604 - accuracy: 0.8485 - val_loss: 2.3687 - val_accuracy: 0.1515
# Epoch 100/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.4604 - accuracy: 0.8485 - val_loss: 2.3645 - val_accuracy: 0.1515

# %%
model.save('/content/drive/MyDrive/AI/11_money/11_money.h5')

# %%
model_Money = load_model('/content/drive/MyDrive/AI/11_money/11_money.h5')

# %%
score=model.evaluate(validation_dataset,verbose=1)
print('Sai số: ',score[0])
print('Độ chính xác: ',score[1])
# Out:
# 1/1 [==============================] - 1s 578ms/step - loss: 2.3645 - accuracy: 0.1515
# Sai số:  2.3644540309906006
# Độ chính xác:  0.1515151560306549

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train','Validation'],loc='upper left')
plt.show()

# %%
img = load_img('/content/500k test.jpg',target_size=(150,150))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
Label = ['0.2k', '0.5k', '1k','2k','5k','10k','20k','50k','100k','200k','500k']
print('Dự đoán là: ',Label[int(np.argmax(model_Money.predict(img),axis=-1))])
# Out:
# Dự đoán là:  0.5k
